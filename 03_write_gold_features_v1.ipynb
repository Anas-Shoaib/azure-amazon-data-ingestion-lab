# %%
storage_account_name = "amazondatalake60104434"
storage_account_key = "<Storage Account Key. Will be posted in the D2L submission>"

spark.conf.set(
    f"fs.azure.account.key.{storage_account_name}.dfs.core.windows.net",
    storage_account_key
)

# %%
enriched_reviews_path = "abfss://processed@amazondatalake60104434.dfs.core.windows.net/enriched_reviews/"
enriched_df = spark.read.parquet(enriched_reviews_path)

# %%
features_v1_df = enriched_df.select(
 "asin",
 "title",
 "brand",
 "price",
 "reviewerID",
 "overall",
 "summary",
 "reviewText",
 "helpful",
 "reviewTime",
 "review_year"
)

# %%
gold_path = "abfss://curated@amazondatalake60104434.dfs.core.windows.net/features_v1/"
features_v1_df.write.mode("overwrite").parquet(gold_path)

# %%
gold_df = spark.read.parquet(gold_path)
gold_df.printSchema()
display(gold_df.limit(5))
print("Final row count:", gold_df.count())
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- reviewerID: string (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- helpful: array (nullable = true)
#  |    |-- element: integer (containsNull = true)
#  |-- reviewTime: string (nullable = true)
#  |-- review_year: integer (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
