# %%
storage_account_name = "amazondatalake60104434"
storage_account_key = "<Storage Account Key. Will be posted in the D2L submission>"

spark.conf.set(
    f"fs.azure.account.key.{storage_account_name}.dfs.core.windows.net",
    storage_account_key
)

# %%
clean_reviews_path = "abfss://processed@amazondatalake60104434.dfs.core.windows.net/clean_reviews/"
clean_reviews_df = spark.read.parquet(clean_reviews_path)

# %%
metadata_path = "abfss://raw@amazondatalake60104434.dfs.core.windows.net/meta_Electronics_fixed.json"
metadata_df = spark.read.json(metadata_path)

# %%
metadata_df = metadata_df.select(
 "asin",
 "title",
 "brand",
 "price"
)

# %%
enriched_df = clean_reviews_df.join(
 metadata_df,
 on="asin",
 how="left"
)

# %%
enriched_out_path = "abfss://processed@amazondatalake60104434.dfs.core.windows.net/enriched_reviews/"
enriched_df.write.mode("overwrite").parquet(enriched_out_path)
